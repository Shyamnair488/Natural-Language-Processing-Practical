# %% [markdown]
# **Aim :**
#  Write a python program to remove stopwords from sentences without inbuilt packages.

# %%
Data="In the midst of a bustling city, under a sky painted with shades of gray, people move about their daily lives, caught in the ebb and flow of time. The sound of traffic blends seamlessly with the chatter of pedestrians, forming a cacophony of urban existence. Despite the constant buzz, individuals find moments of solace, sitting on park benches or leaning against weathered buildings. Through the haze of routine, life's simple pleasures shine like stars in the night sky, reminding us of the beauty that lies within the ordinary."

# %%
d1=Data
Data
# Out:
# "In the midst of a bustling city, under a sky painted with shades of gray, people move about their daily lives, caught in the ebb and flow of time. The sound of traffic blends seamlessly with the chatter of pedestrians, forming a cacophony of urban existence. Despite the constant buzz, individuals find moments of solace, sitting on park benches or leaning against weathered buildings. Through the haze of routine, life's simple pleasures shine like stars in the night sky, reminding us of the beauty that lies within the ordinary."

# %%
SWdata=["a","an"]
print(SWdata)
# Out:
# ['a', 'an']

# %%
def remove_stopwords(sentence, stopwords):
    words = sentence.split()
    filtered_words = [word for word in words if word.lower() not in stopwords]
    filtered_sentence = ' '.join(filtered_words)
    print(filtered_sentence)

def main():
    input_sentence = Data
    stopwords =SWdata

    filtered_sentence = remove_stopwords(input_sentence, stopwords)


if __name__ == "__main__":
    main()
# Out:
# In the midst of bustling city, under sky painted with shades of gray, people move about their daily lives, caught in the ebb and flow of time. The sound of traffic blends seamlessly with the chatter of pedestrians, forming cacophony of urban existence. Despite the constant buzz, individuals find moments of solace, sitting on park benches or leaning against weathered buildings. Through the haze of routine, life's simple pleasures shine like stars in the night sky, reminding us of the beauty that lies within the ordinary.

# %% [markdown]
# Using NLP

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
l=len(stopwords.words("english"))
print(f'total stopword:{l}')
# Out:
# total stopword:179

# %%
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
Stopwords=list(stopwords.words('english'))

# %%
def remove_stopwords(sentence, stopwords):
    words = sentence.split()
    filtered_words = [word for word in words if word.lower() not in stopwords]
    filtered_sentence = ' '.join(filtered_words)
    return filtered_sentence

def main():
    input_sentence = Data
    stopwords =Stopwords

    filtered_sentence = remove_stopwords(input_sentence, stopwords)
    print("Filtered sentence:", filtered_sentence)

if __name__ == "__main__":
    main()
# Out:
# Filtered sentence: midst bustling city, sky painted shades gray, people move daily lives, caught ebb flow time. sound traffic blends seamlessly chatter pedestrians, forming cacophony urban existence. Despite constant buzz, individuals find moments solace, sitting park benches leaning weathered buildings. haze routine, life's simple pleasures shine like stars night sky, reminding us beauty lies within ordinary.

# %%
pip install gensim

# %%
from gensim.parsing.preprocessing import remove_stopwords

# %%
filtered_text = remove_stopwords(Data)
filtered_text
# Out:
# "In midst bustling city, sky painted shades gray, people daily lives, caught ebb flow time. The sound traffic blends seamlessly chatter pedestrians, forming cacophony urban existence. Despite constant buzz, individuals moments solace, sitting park benches leaning weathered buildings. Through haze routine, life's simple pleasures shine like stars night sky, reminding beauty lies ordinary."

# %%
pip install spacy

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(Data)

# %%
doc
# Out:
# In the midst of a bustling city, under a sky painted with shades of gray, people move about their daily lives, caught in the ebb and flow of time. The sound of traffic blends seamlessly with the chatter of pedestrians, forming a cacophony of urban existence. Despite the constant buzz, individuals find moments of solace, sitting on park benches or leaning against weathered buildings. Through the haze of routine, life's simple pleasures shine like stars in the night sky, reminding us of the beauty that lies within the ordinary.
