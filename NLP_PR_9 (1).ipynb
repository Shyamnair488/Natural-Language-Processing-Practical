# %% [markdown]
# **PRACTICAL 09 | NATURAL LANGUAGE PROCESSING**

# %% [markdown]
# VEDANT DUDDALWAR | 60

# %% [markdown]
# **IMPLEMENT N-GRAM LANGUAGE MODEL WITH NLTK**

# %%
import string
import random
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('reuters')
from nltk.corpus import reuters
from nltk import FreqDist
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package reuters to /root/nltk_data...

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
sents =reuters.sents()

# %%
stop_words = set(stopwords.words('english'))
string.punctuation = string.punctuation +'"'+'"'+'-'+'''+'''+'—'
print(string.punctuation)
removal_list = list(stop_words) + list(string.punctuation)+ ['lt','rt']
print(removal_list)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~""-+—
# ['out', "hasn't", 'nor', 'so', 'such', 'where', 'these', 'most', 'to', 'only', 'with', 'weren', "doesn't", 'why', 're', "couldn't", "you'd", 'from', 'itself', 'hers', 'all', "that'll", 'doesn', 'ours', 'yourself', 'who', 'further', 'm', "she's", 'under', 'again', 'me', "you'll", 'doing', 'how', "didn't", 'while', 'him', 'the', 's', 'on', "shouldn't", 'has', 'after', 'o', 'theirs', 'ma', 'mustn', 'be', 'mightn', 'not', 'our', 'few', "haven't", 'had', 'more', 'll', 'himself', 'once', 'off', 'her', "needn't", 'this', 'did', 'for', 'myself', "you've", 'yours', 'now', 'his', 'as', 'herself', 'too', 'couldn', 'at', "mightn't", "aren't", 'does', 'own', 'ain', 'she', 'when', 'having', 'above', 'about', 'some', 'what', 'before', 'ourselves', 'until', 'their', 'will', "shan't", 'below', 'should', 'just', 'but', 'my', 'during', 't', 'in', 'here', "hadn't", 'it', "wasn't", 'y', 'if', 'hadn', 'won', 'by', "it's", 'them', 'we', 'he', 'were', 'd', "wouldn't", 'that', 'and', 'is', "don't", "won't", 'am', 'have', 've', 'i', 'a', 'very', 'no', 'isn', "isn't", 'been', 'than', 'up', 'can', 'whom', 'because', 'both', 'any', 'against', 'between', 'other', 'of', 'there', 'don', 'each', 'themselves', 'wasn', 'shan', 'then', 'same', 'your', "mustn't", 'hasn', 'into', 'was', 'those', 'its', "you're", 'yourselves', 'didn', "should've", 'through', 'needn', 'being', 'are', 'or', 'shouldn', 'they', 'an', 'down', "weren't", 'which', 'aren', 'you', 'haven', 'wouldn', 'do', 'over', '!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~', '"', '"', '-', '+', '—', 'lt', 'rt']

# %%
from nltk import ngrams

# %%
unigram=[]
bigram=[]
trigram=[]
tokenized_text=[]
for sentence in sents:
  sentence = list(map(lambda x:x.lower(),sentence))
  for word in sentence:
    if word== '.':
      sentence.remove(word)
    else:
      unigram.append(word)
  tokenized_text.append(sentence)
  bigram.extend(list(ngrams(sentence, 2,pad_left=True, pad_right=True)))
  trigram.extend(list(ngrams(sentence, 3, pad_left=True, pad_right=True)))

# %%
from collections import defaultdict
from collections import Counter

# %%
freq_bi = FreqDist(bigram)
freq_tri = FreqDist(trigram)

# %%
d = defaultdict(Counter)
for a, b, c in freq_tri:
  if a is not None and b is not None and c is not None:
    d[(a, b)][c] += freq_tri[(a, b, c)]

# %%
s=''
def pick_word(counter):
  "Chooses a random element."
  return random.choice(list(counter.elements()))
prefix = "he", "said"
print(" ".join(prefix))
s = " ".join(prefix)
for i in range(19):
  suffix = pick_word(d[prefix])
  s=s+' '+suffix
  print(s)
  prefix = prefix[1], suffix
# Out:
# he said
# he said he
# he said he bought
# he said he bought 7
# he said he bought 7 ,
# he said he bought 7 , 625
# he said he bought 7 , 625 sales
# he said he bought 7 , 625 sales 19
# he said he bought 7 , 625 sales 19 5
# he said he bought 7 , 625 sales 19 5 mln
# he said he bought 7 , 625 sales 19 5 mln dlrs
# he said he bought 7 , 625 sales 19 5 mln dlrs on
# he said he bought 7 , 625 sales 19 5 mln dlrs on sales
# he said he bought 7 , 625 sales 19 5 mln dlrs on sales of
# he said he bought 7 , 625 sales 19 5 mln dlrs on sales of westar
# he said he bought 7 , 625 sales 19 5 mln dlrs on sales of westar timber
# he said he bought 7 , 625 sales 19 5 mln dlrs on sales of westar timber '
# he said he bought 7 , 625 sales 19 5 mln dlrs on sales of westar timber ' s
# he said he bought 7 , 625 sales 19 5 mln dlrs on sales of westar timber ' s graphic
# he said he bought 7 , 625 sales 19 5 mln dlrs on sales of westar timber ' s graphic arts
