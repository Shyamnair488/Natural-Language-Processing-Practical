# %% [markdown]
# AIM : Implement N-gram language model with nltk

# %%
import string
import random
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('reuters')
from nltk.corpus import reuters
from nltk import FreqDist
from nltk import ngrams
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package reuters to /root/nltk_data...
# [nltk_data]   Package reuters is already up-to-date!

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
sents =reuters.sents()

# %%
stop_words = set(stopwords.words('english'))
string.punctuation = string.punctuation +'"'+'"'+'-'+'''+'''+'—'
print(string.punctuation)
removal_list = list(stop_words) + list(string.punctuation)+ ['lt','rt']
print(removal_list)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~""-+—
# ['what', 'which', 'd', 'am', 'up', 'into', "don't", "should've", 'they', 'and', "won't", "she's", 'is', 'been', 'but', 'will', 'your', 'for', 'too', 'why', 'other', 'how', 'nor', 'y', 'i', "you'll", 'that', "aren't", 'yours', 'its', 'm', 'being', "you'd", 'didn', 'before', "you've", 'such', 'myself', 'not', 'where', 're', 'down', "weren't", 'again', "hadn't", 'wasn', 'herself', 'has', 'of', 'll', "wasn't", 'through', 's', 'so', 'both', 'who', 'have', 'do', 'some', 'it', 'weren', "mightn't", 'these', 'were', 'shouldn', 'an', 'don', 'them', 'just', 'from', 'on', 'ourselves', 'out', 'off', 'aren', "you're", 'or', 'here', 'as', 'you', 'about', 'same', 'her', 'only', 'our', 'themselves', 'no', 'hasn', 'ain', 'are', 'shan', 'was', 'very', 'against', 'when', 'theirs', 'a', 'be', 'few', 'by', 'until', 'me', 'yourselves', 'my', 'him', 'than', 'ma', "shan't", 'wouldn', 'any', 'most', 'doesn', 'now', "didn't", 'once', 'while', 'above', 'couldn', 'needn', 'we', 't', 'at', 'this', 'further', 'all', 'more', 'with', 'the', 'own', "hasn't", 'his', 'he', "haven't", 'itself', 'she', 'whom', 'had', 'doing', 'isn', 'over', 'should', "that'll", 'mightn', 'yourself', 've', "it's", 'won', 'because', 'haven', "wouldn't", 'under', 'hadn', 'having', 'then', 'ours', 'those', 'in', "needn't", 'did', 'there', 'each', 'their', 'during', 'mustn', 'does', 'hers', "mustn't", "couldn't", 'himself', "isn't", 'after', 'between', 'to', 'if', 'can', "doesn't", 'o', "shouldn't", 'below', '!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~', '"', '"', '-', '+', '—', 'lt', 'rt']

# %%
unigram=[]
bigram=[]
trigram=[]
tokenized_text=[]
for sentence in sents:
  sentence = list(map(lambda x:x.lower(),sentence))
  for word in sentence:
    if word== '.':
      sentence.remove(word)
    else:
      unigram.append(word)
  tokenized_text.append(sentence)
  bigram.extend(list(ngrams(sentence, 2,pad_left=True, pad_right=True)))
  trigram.extend(list(ngrams(sentence, 3, pad_left=True, pad_right=True)))

# %%
from collections import defaultdict
from collections import Counter

# %%
freq_bi = FreqDist(bigram)
freq_tri = FreqDist(trigram)

# %%
d = defaultdict(Counter)
for a, b, c in freq_tri:
  if a is not None and b is not None and c is not None:
    d[(a, b)][c] += freq_tri[(a, b, c)]

# %%
s=''
def pick_word(counter):
  "Chooses a random element."
  return random.choice(list(counter.elements()))
prefix = "he", "said"
print(" ".join(prefix))
s = " ".join(prefix)
for i in range(19):
  suffix = pick_word(d[prefix])
  s=s+' '+suffix
  print(s)
  prefix = prefix[1], suffix
# Out:
# he said
# he said a
# he said a 1
# he said a 1 1
# he said a 1 1 mln
# he said a 1 1 mln note
# he said a 1 1 mln note :
# he said a 1 1 mln note : shr
# he said a 1 1 mln note : shr after
# he said a 1 1 mln note : shr after preferred
# he said a 1 1 mln note : shr after preferred dividends
# he said a 1 1 mln note : shr after preferred dividends in
# he said a 1 1 mln note : shr after preferred dividends in the
# he said a 1 1 mln note : shr after preferred dividends in the area
# he said a 1 1 mln note : shr after preferred dividends in the area were
# he said a 1 1 mln note : shr after preferred dividends in the area were favorable
# he said a 1 1 mln note : shr after preferred dividends in the area were favorable for
# he said a 1 1 mln note : shr after preferred dividends in the area were favorable for the
# he said a 1 1 mln note : shr after preferred dividends in the area were favorable for the products
# he said a 1 1 mln note : shr after preferred dividends in the area were favorable for the products sell
